# %% [markdown]
# <a href="https://colab.research.google.com/github/ChastityB/Placeholder/blob/main/Redo_of_Project_2_Part_1_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project 2 - Part 1 (Core)
#
# Chastity Benton
#
# March 2022

# %% [markdown]
# #Load the Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##First Choice: Dataset 1

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Coding Dojo/02 Machine Learning/03 Week 3: Classification Models/Assignment Exercise/Project Part 2/healthcare-dataset-stroke-data.csv')
df1.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ##Task Questions

# %% [markdown]
# ###*
# **1) Source of data**
# This dataset was can be found on [Kaggle](https://www.kaggle.com/fedesoriano/stroke-prediction-dataset).
#
# **2) Brief description of the data**
# This dataset is used to predict whether a patient is likely to get a stroke based on the dataset.
#
# **3)What is the target?**
# The target is finding out if a patient is prone to having a stroke
#
# **4) Is this a classification or regression problem?**
# This is a classification problem
#
# **5) How many features are there?**
# There are 12 features
#
# **6)How many rows of data?**
# 5110 rows
#
# **7) what, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?**
# Interpreting the missing or inconsistent values correctly.

# %% [markdown]
# #Second Choice: Dataset 2

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Coding Dojo/02 Machine Learning/03 Week 3: Classification Models/Assignment Exercise/Project Part 2/diabetic_data.csv')
df2.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %% [markdown]
# ##Task Questions

# %% [markdown]
# ###*
# **1) Source of data**
# This dataset was can be found on [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Diabetes+130-US+hospitals+for+years+1999-2008).
#
#
# **2) Brief description of the data**
# This dataset is used to predict whether a diabetic patient was re-admitted to the hospital or not.
#
# **3)What is the target?**
# The target is readmitted
#
# **4) Is this a classification or regression problem?**
# This is a classification problem
#
# **5) How many features are there?**
# There are 50 features
#
# **6)How many rows of data?**
# 101766 rows
#
# **7) what, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?**
#   * Removing unnecessary data. There is a lot of ? aka nan's in the data that need to be addressed and removed.
#   * Truly determining if readmittance is the target.
#   * Understanding each of the categories.
